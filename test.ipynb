# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
import os 
os.getcwd()
os.listdir()
# Out:
# ['.git',
#  '.gitignore',
#  '.ipynb_checkpoints',
#  '0-1-2-3.jpg',
#  'app.py',
#  'Brodatz Texture',
#  'LICENSE',
#  'logs',
#  'README.md',
#  'requirements.txt',
#  'research',
#  'setup.py',
#  'src',
#  'template.py',
#  'test.ipynb',
#  'test.py']

# %%
file_bytes= np.asarray('0-1-2-3.jpg',dtype=np.uint8)
img= cv2.imdecode(file_bytes,1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 file_bytes= np.asarray('0-1-2-3.jpg',dtype=np.uint8)
#       2 img= cv2.imdecode(file_bytes,1)
#
# ValueError: invalid literal for int() with base 10: '0-1-2-3.jpg'

# %%
from skimage import io
img=io.imread(r"C:\Texture_detection\Texture_detection\0-1-2-3.jpg")
plt.imshow(img)
