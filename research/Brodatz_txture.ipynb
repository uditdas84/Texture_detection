# %%
import urllib.request
from PIL import Image 
import os
import cv2 
import numpy 
import matplotlib.pyplot as plt 
from skimage import io
# %matplotlib inline
# Out:
# C:\Users\LENOVO\anaconda3\Lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated
#   "class": algorithms.Blowfish,

# %%
parent_dir=r"C:\Users\LENOVO\OneDrive\Desktop\Texture Detection"
dir_name="Brodatz Texture"
path=os.path.join(parent_dir,dir_name)
os.mkdir(path)
print("directory '%s' created at" %dir_name)
# Out:
# directory 'Brodatz Texture' created at

# %%
def dl_img(url,file_path,file_name):
    full_path= file_path+file_name+".jpg"
    urllib.request.urlretrieve(url,full_path)

# %%
url=[]
for i in range(1,113):
    url.append(f"https://www.ux.uis.no/~tranden/brodatz/D{i}.gif")

# %%
url
# Out:
# ['https://www.ux.uis.no/~tranden/brodatz/D1.gif',
#  'https://www.ux.uis.no/~tranden/brodatz/D2.gif',
#  'https://www.ux.uis.no/~tranden/brodatz/D3.gif',
#  'https://www.ux.uis.no/~tranden/brodatz/D4.gif',
#  'https://www.ux.uis.no/~tranden/brodatz/D5.gif',
#  'https://www.ux.uis.no/~tranden/brodatz/D6.gif',
#  'https://www.ux.uis.no/~tranden/brodatz/D7.gif',
#  'https://www.ux.uis.no/~tranden/brodatz/D8.gif',
#  'https://www.ux.uis.no/~tranden/brodatz/D9.gif',
#  'https://www.ux.uis.no/~tranden/brodatz/D10.gif',
#  'https://www.ux.uis.no/~tranden/brodatz/D11.gif',
#  'https://www.ux.uis.no/~tranden/brodatz/D12.gif',
#  'https://www.ux.uis.no/~tranden/brodatz/D13.gif',
#  'https://www.ux.uis.no/~tranden/brodatz/D14.gif',
#  'https://www.ux.uis.no/~tranden/brodatz/D15.gif',
#  'https://www.ux.uis.no/~tranden/brodatz/D16.gif',
#  'https://www.ux.uis.no/~tranden/brodatz/D17.gif',
#  'https://www.ux.uis.no/~tranden/brodatz/D18.gif',
#  'https://www.ux.uis.no/~tranden/brodatz/D19.gif',
# ...

# %%
img_path=r'C:\Users\LENOVO\OneDrive\Desktop\Texture Detection\Brodatz Texture'
for i in range(112):
    urllib.request.urlretrieve(f'https://www.ux.uis.no/~tranden/brodatz/D{i}.gif',img_path+".jpg")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[11], line 3
#       1 img_path=r'C:\Users\LENOVO\OneDrive\Desktop\Texture Detection\Brodatz Texture'
#       2 for i in range(112):
# ----> 3     urllib.request.urlretrieve(f'https://www.ux.uis.no/~tranden/brodatz/D{i}.gif',img_path+".jpg")
#
# File ~\anaconda3\Lib\urllib\request.py:241, in urlretrieve(url, filename, reporthook, data)
#     224 """
#     225 Retrieve a URL into a temporary location on disk.
#     226
#    (...)
#     237 data file as well as the resulting HTTPMessage object.
#     238 """
#     239 url_type, path = _splittype(url)
# --> 241 with contextlib.closing(urlopen(url, data)) as fp:
#     242     headers = fp.info()
#     244     # Just return the local path and the "headers" for file://
#     245     # URLs. No sense in performing a copy unless requested.
#
# ...

# %%
os.getcwd()
# Out:
# 'C:\\Users\\LENOVO\\OneDrive\\Desktop\\Texture Detection'

# %%
urllib.request.urlretrieve(r'https://www.ux.uis.no/~tranden/brodatz/D1.gif',img_path,"1.jpg")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 urllib.request.urlretrieve(r'https://www.ux.uis.no/~tranden/brodatz/D1.gif',img_path,"1.jpg")
#
# File ~\anaconda3\Lib\urllib\request.py:251, in urlretrieve(url, filename, reporthook, data)
#     249 # Handle temporary file setup.
#     250 if filename:
# --> 251     tfp = open(filename, 'wb')
#     252 else:
#     253     tfp = tempfile.NamedTemporaryFile(delete=False)
#
# PermissionError: [Errno 13] Permission denied: 'C:\\Users\\LENOVO\\OneDrive\\Desktop\\Texture Detection\\Brodatz Texture'

# %%
for i in range(112):
    res = requests.get(url[i], stream = True)
    if res.status_code == 200:
        with open(file_name,'wb') as f:
            shutil.copyfileobj(res.raw, f)
        print('Image sucessfully Downloaded: ',file_name)
    else:
        print('Image Couldn\'t be retrieved')

# %%
path=os.getcwd()

# %%
os.chdir(path+"\Brodatz Texture")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\LENOVO\\OneDrive\\Desktop\\Texture Detection\\Brodatz Texture'

# %%
import requests # request img from web
import shutil # save img locally



for i in range(112):
    res = requests.get(url[i], stream = True)
    if res.status_code == 200:
        with open(str(i)+'.gif','wb') as f:
            shutil.copyfileobj(res.raw, f)
        print('Image sucessfully Downloaded: '+str(i)+'.gif')
    else:
        print('Image Couldn\'t be retrieved')
# Out:
# Image sucessfully Downloaded: 0.gif
# Image sucessfully Downloaded: 1.gif
# Image sucessfully Downloaded: 2.gif
# Image sucessfully Downloaded: 3.gif
# Image sucessfully Downloaded: 4.gif
# Image sucessfully Downloaded: 5.gif
# Image sucessfully Downloaded: 6.gif
# Image sucessfully Downloaded: 7.gif
# Image sucessfully Downloaded: 8.gif
# Image sucessfully Downloaded: 9.gif
# Image sucessfully Downloaded: 10.gif
# Image sucessfully Downloaded: 11.gif
# Image sucessfully Downloaded: 12.gif
# Image Couldn't be retrieved
# Image sucessfully Downloaded: 14.gif
# Image sucessfully Downloaded: 15.gif
# Image sucessfully Downloaded: 16.gif
# Image sucessfully Downloaded: 17.gif
# Image sucessfully Downloaded: 18.gif
# Image sucessfully Downloaded: 19.gif
# Image sucessfully Downloaded: 20.gif
# Image sucessfully Downloaded: 21.gif
# Image sucessfully Downloaded: 22.gif
# Image sucessfully Downloaded: 23.gif
# Image sucessfully Downloaded: 24.gif
# Image sucessfully Downloaded: 25.gif
# ...

# %%
os.getcwd()
# Out:
# 'C:\\Users\\LENOVO\\OneDrive\\Desktop\\Texture Detection\\Brodatz Texture'

# %%
os.chdir('./Brodatz Texture/')

# %%
os.listdir()
# Out:
# ['0-1-2-3.jpg',
#  '0.gif',
#  '0123.jpg',
#  '1.gif',
#  '10.gif',
#  '100.gif',
#  '101.gif',
#  '102.gif',
#  '103.gif',
#  '104.gif',
#  '105.gif',
#  '106.gif',
#  '107.gif',
#  '108.gif',
#  '109.gif',
#  '11.gif',
#  '110.gif',
#  '111.gif',
#  '12.gif',
#  '14.gif',
#  '15.gif',
#  '16.gif',
#  '17.gif',
#  '18.gif',
#  '19.gif',
#  '2.gif',
#  '20.gif',
#  '21.gif',
#  '22.gif',
#  '23.gif',
#  '24.gif',
#  '25.gif',
#  '26.gif',
#  '27.gif',
#  '28.gif',
#  '29.gif',
#  '3.gif',
#  '30.gif',
#  '31.gif',
#  '32.gif',
#  '33.gif',
#  '34.gif',
#  '35.gif',
#  '36.gif',
#  '37.gif',
#  '38.gif',
#  '39.gif',
#  '4.gif',
#  '40.gif',
#  '41.gif',
#  '42.gif',
#  '43.gif',
#  '44.gif',
#  '45.gif',
#  '46.gif',
#  '47.gif',
#  '48.gif',
#  '49.gif',
#  '5.gif',
#  '50.gif',
#  '51.gif',
#  '52.gif',
#  '53.gif',
#  '54.gif',
#  '55.gif',
#  '56.gif',
#  '57.gif',
#  '58.gif',
#  '59.gif',
#  '6.gif',
#  '60.gif',
#  '61.gif',
#  '62.gif',
#  '63.gif',
#  '64.gif',
#  '65.gif',
# ...

# %%
os.path.exists(img_path)
# Out:
# True

# %%
from PIL import Image
Image.open('1.gif',)
# Out:
# <PIL.GifImagePlugin.GifImageFile image mode=L size=640x640>

# %%
# opening up of images 
img1 = Image.open("0.gif") 
img2 = Image.open("25.gif") 
img3 = Image.open("70.gif")
img4 = Image.open("71.gif")

img1_size = img1.resize((180,180)) 
img2_size = img2.resize((180,180)) 
img3_size = img3.resize((180,180))
img4_size = img4.resize((180,180))

# creating a new image and pasting the 
# images 
white_image = Image.new('L',(360, 360), "white") 

# pasting the first image 
white_image.paste(img1_size,(0, 0)) 

# pasting the second image
white_image.paste(img2_size,(180, 0))
                  
# pasting the third image
white_image.paste(img3_size,(0, 180))
                  
# pasting the fourth image
white_image.paste(img4_size,(180, 180))

plt.imshow(white_image)

# %%
white_image.save('collage2.jpg')

# %%
# !pip install scikit-image

# %%
# Update pip
# !pip install -U pip
# Install scikit-image
# !pip install -U scikit-image
# Out:
# ...
#   Obtaining dependency information for pip from https://files.pythonhosted.org/packages/8a/6a/19e9fe04fca059ccf770861c7d5721ab4c2aebc539889e97c7977528a53b/pip-24.0-py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    - -------------------------------------- 0.1/2.1 MB ? eta -:--:--
#    - -------------------------------------- 0.1/2.1 MB 1.3 MB/s eta 0:00:02
#    -- ------------------------------------- 0.1/2.1 MB 1.2 MB/s eta 0:00:02
#    --- ------------------------------------ 0.2/2.1 MB 1.1 MB/s eta 0:00:02
#    --- ------------------------------------ 0.2/2.1 MB 980.4 kB/s eta 0:00:02
#    ---- ----------------------------------- 0.2/2.1 MB 981.9 kB/s eta 0:00:02
#    ----- ---------------------------------- 0.3/2.1 MB 962.4 kB/s eta 0:00:02
#    ----- ---------------------------------- 0.3/2.1 MB 871.5 kB/s eta 0:00:03
# ...

# %%
os.getcwd()
os.chdir('./Brodatz Texture/')

# %%
PATCH_SIZE= 35

image = io.imread('0123.jpg')
plt.imshow(image,cmap='gray')

# %%
import numpy as np

# %%
GLCM= graycomatrix(image,[1],[0,np.pi/4,np.pi/2,3*np.pi/4])
a= graycoprops(GLCM,'energy')[0,0]

# %%
first_locations= [(50,50),(100,100),(150,150)]
first_patches=[]
for loc in first_locations:
    first_patches.append(image[loc[0]:loc[0]+PATCH_SIZE,
                               loc[1]:loc[1]+PATCH_SIZE])

    
second_locations= [(50,180),(100,230),(150,280)]
second_patches=[]
for loc in second_locations:
    second_patches.append(image[loc[0]:loc[0]+PATCH_SIZE,
                               loc[1]:loc[1]+PATCH_SIZE])
    
third_locations= [(180,50),(230,100),(280,150)]
third_patches=[]
for loc in third_locations:
    third_patches.append(image[loc[0]:loc[0]+PATCH_SIZE,
                               loc[1]:loc[1]+PATCH_SIZE])
    
third_locations= [(180,180),(230,230),(280,280)]
third_patches=[]
for loc in first_locations:
    third_patches.append(image[loc[0]:loc[0]+PATCH_SIZE,
                               loc[1]:loc[1]+PATCH_SIZE])

# %%
plt.imshow(image[50:100,50:500])

# %%
# compute some GLCM properties
